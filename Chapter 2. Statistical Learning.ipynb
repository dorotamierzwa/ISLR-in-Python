# %% [markdown]
# # An Introduction to Statistical Learning with Applications in R by G. James, D. Witten, T. Hastie and R. Tibshirani
#
# Applied exercises done in Python, numbered as in the book.
#
# [College and Auto datasets](http://www-bcf.usc.edu/~gareth/ISL/data.html)

# %% [markdown]
# **8. (a) Use the read.csv() function to read the data into R. Call the loaded data college. Make sure that you have the directory set to the correct location for the data.**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set()

# %%
college = pd.read_csv('College.csv')
college.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %% [markdown]
# ** 8. (b) Make *Private* the first data column and use college names as an index (rownames() in R).**

# %%
college.index = college['Unnamed: 0']
del college['Unnamed: 0']
college.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Unnamed: 0
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Unnamed: 0
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %% [markdown]
# **8. (c) Produce a numerical summary of the variables in the data set.**

# %%
college.describe() # applies only to continuous variables
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
college['Private'].value_counts() # applies to the single categorical column in the dataset
# Out:
# Yes    565
# No     212
# Name: Private, dtype: int64

# %% [markdown]
# **8. (c) Produce a scatterplot matrix of the first ten columns or variables of the data.**

# %%
sns.pairplot(college[college.columns[0:10]])

# %% [markdown]
# **8. (c) Use the plot() function to produce side-by-side boxplots of Outstate versus Private.**

# %%
sns.boxplot(x='Private', y='Outstate', data=college)

# %% [markdown]
# ** 8. (c) Create a new qualitative variable, called Elite, by binning the Top10perc variable. We are going to divide universities into two groups based on whether or not the proportion of students coming from the top 10% of their high school classes exceeds 50 %.**
#
# **See how many elite universities there are. Produce side-by-side boxplots of Outstate versus Elite.
# **

# %%
college['Elite'] = np.where(college['Top10perc']>50, 'Yes', 'No')

# %%
college['Elite'].value_counts()
# Out:
# No     699
# Yes     78
# Name: Elite, dtype: int64

# %%
sns.boxplot(x='Elite', y='Outstate', data=college)

# %% [markdown]
# **8. (c) Produce some histograms with differing numbers of bins for a few of the quantitative variables. Divide the print window into four regions so that four plots can be made simultaneously.**

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize = (12,10))
college['Apps'].hist(ax=axes[0,0], bins=30).set_xlabel('Apps')
college['Accept'].hist(ax=axes[0,1], bins=30).set_xlabel('Accept')
college['Top10perc'].hist(ax=axes[1,0], bins=10).set_xlabel('Top10perc')
college['Top25perc'].hist(ax=axes[1,1], bins=10).set_xlabel('Top25perc')
# Out:
# Text(0.5,0,'Top25perc')

# %% [markdown]
# **8. (c) Continue exploring the data, and provide a brief summary of what you discover.**

# %%
sns.clustermap(college.corr(), cmap='magma')

# %% [markdown]
# The above clustermap shows all quantitative variables and how they correlate, clustered in similar groups. The highest correlation can be observed for numer of students enrolled, accepted, those who applied and full-time undergraduates. This seems pretty intuitive, the more applications, the more students are accepted and the more of them are enrolled. We can also observe positive relation between top 10% and 25% of students, as one is a contituent of another. The same refers to Terminal and PhD degree.
# On the other hand student/faculty ratio stands out as the one having the most negative relations. Number of students per faculty appears to have an inverse relation with out-of-state tuition, expenditure per student and percent of alumni who donate.

# %% [markdown]
# **9. (a) This exercise involves the Auto data set studied in the lab. Make sure that the missing values have been removed from the data. Which of the predictors are quantitative, and which are qualitative?**

# %%
auto = pd.read_csv('Auto.csv', na_values=np.nan)
auto.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
# 3  16.0          8         304.0        150    3433          12.0    70
# 4  17.0          8         302.0        140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
auto.dtypes # horsepower as object points that there are other values than numbers.  pd.to_numeric(auto['horsepower'] raises error about values "?")
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# year              int64
# origin            int64
# name             object
# dtype: object

# %%
auto = auto[auto['horsepower'] != "?"] # dropping null values
auto['horsepower'] = auto['horsepower'].astype(float) # change horsepower data type to float

# %% [markdown]
# Name and origin are qualitative variables, the others are quantitative.

# %% [markdown]
# ** 9. (b), (c) What is the range, mean and standard deviation of each quantitative predictor? **

# %%
auto.describe(include='all')
# Out:
#                mpg   cylinders  displacement  horsepower       weight  \
# count   392.000000  392.000000    392.000000  392.000000   392.000000
# unique         NaN         NaN           NaN         NaN          NaN
# top            NaN         NaN           NaN         NaN          NaN
# freq           NaN         NaN           NaN         NaN          NaN
# mean     23.445918    5.471939    194.411990  104.469388  2977.584184
# std       7.805007    1.705783    104.644004   38.491160   849.402560
# min       9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%      17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%      22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%      29.000000    8.000000    275.750000  126.000000  3614.750000
# max      46.600000    8.000000    455.000000  230.000000  5140.000000
#
#         acceleration        year      origin            name
# count     392.000000  392.000000  392.000000             392
# ...

# %% [markdown]
# ** 9. (d) Now remove the 10th through 85th observations. What is the range, mean, and standard deviation of each predictor in the subset of the data that remains?**

# %%
auto_1 = auto.drop(auto.index[10:86])
auto_1.describe()
# Out:
#               mpg   cylinders  displacement  horsepower      weight  \
# count  316.000000  316.000000    316.000000  316.000000   316.00000
# mean    24.407595    5.373418    187.512658  100.848101  2936.53481
# std      7.863285    1.654179    100.114616   35.954147   811.87445
# min     11.000000    3.000000     68.000000   46.000000  1649.00000
# 25%     18.000000    4.000000    100.250000   75.000000  2213.75000
# 50%     23.950000    4.000000    145.500000   90.000000  2792.50000
# 75%     30.550000    6.000000    250.000000  115.000000  3508.00000
# max     46.600000    8.000000    455.000000  230.000000  4997.00000
#
#        acceleration        year      origin
# count    316.000000  316.000000  316.000000
# mean      15.717405   77.136076    1.601266
# std        2.713876    3.123464    0.819910
# min        8.500000   70.000000    1.000000
# 25%       14.000000   75.000000    1.000000
# 50%       15.500000   77.000000    1.000000
# ...

# %% [markdown]
# **9. (e) Using the full data set, investigate the predictors graphically, using scatterplots or other tools of your choice. Create some plots highlighting the relationships among the predictors. Comment on your findings.**

# %%
sns.pairplot(auto)

# %% [markdown]
# Looking at year, we can see that acceleration of cars is slightly increasing, the same trend, but stronger, refers to mpg. At the same time on average displacement, horsepower and weight values decrese within this 10 year period.
# Weigth and displacement show close to a linear relation, when one increases, so does the other. Similar, but inverse relation exists between weight,displacement, horsepower and mpg, where mpg steadily decreses.

# %% [markdown]
# **9. (f) Suppose that we wish to predict gas mileage (mpg) on the basis of the other variables. Do your plots suggest that any of the other variables might be useful in predicting mpg? Justify your answer.**

# %% [markdown]
# Apart from acceleration values, mpg seems to have clear relations with all the other variables. Therefore we can use them in predicting mpg value - it tends to increase with time and decrease with dicplacement, horsepower, weight and cylinders increasing. Sample of 300 cars may not be representative however, especially taking into account that year value covers only 12 years.

# %% [markdown]
# **10. (a) Load in the Boston data set. The Boston data set is part of the MASS library in R. I saved it as csv in Rstudio and loaded with Python
# How many rows are in this data set? How many columns? What do the rows and columns represent?**

# %%
boston = pd.read_csv("Boston.csv")
boston.index = boston['Unnamed: 0']
del boston['Unnamed: 0']
boston.head()
# Out:
#                crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# Unnamed: 0
# 1           0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 2           0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 3           0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 4           0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 5           0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
#
#             ptratio   black  lstat  medv
# Unnamed: 0
# 1              15.3  396.90   4.98  24.0
# 2              17.8  396.90   9.14  21.6
# 3              17.8  392.83   4.03  34.7
# 4              18.7  394.63   2.94  33.4
# 5              18.7  396.90   5.33  36.2

# %% [markdown]
# * crim - per capita crime rate by town.
# * zn - proportion of residential land zoned for lots over 25,000 sq.ft.
# * indus - proportion of non-retail business acres per town.
# * chas - Charles River dummy variable (= 1 if tract bounds river; 0 otherwise).
# * nox - nitrogen oxides concentration (parts per 10 million).
# * rm - average number of rooms per dwelling.
# * age - proportion of owner-occupied units built prior to 1940.
# * dis - weighted mean of distances to five Boston employment centres.
# * rad index of accessibility to radial highways.
# * tax - full-value property-tax rate per USD10,000.
# * ptratio - pupil-teacher ratio by town.
# * black - 1000(Bk − 0.63)2 where Bk is the proportion of blacks by town.
# * lstat - lower status of the population (percent).
# * medv - median value of owner-occupied homes in USD1000s.
# [source](https://cran.r-project.org/web/packages/MASS/MASS.pdf)

# %%
boston.shape
# Out:
# (506, 14)

# %% [markdown]
# **10. (b) Make some pairwise scatterplots of the predictors (columns) in this data set. Describe your findings.**

# %%
sns.pairplot(data=boston)

# %%
fig = plt.subplots(figsize = (12,4))
sns.regplot(x='medv', y='rm', data=boston, color='lightblue')
sns.regplot(x='lstat', y='rm', data=boston, color='gray')

# %% [markdown]
# Number of rooms per dwelling and median value of owner-occupied homes tends to be positively correlated. The more rooms, the higher the value of property. One the other hand, as number of rooms decreases, the percent of low status population increases. Number of rooms can point to the status.

# %%
boston.plot.scatter(x='dis', y='lstat', c='ptratio', figsize = (12,6)).set_xlabel('crim')
# Out:
# Text(0.5,0,'crim')

# %% [markdown]
# The lower the weighted distance to employment centers, the higher the percent of lower status population.
# Pupil-teacher ratio tends to be the highest for higher percent of lower status population.

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize = (16,6))
ax1.scatter(x='nox', y='medv', data=boston)
ax1.set_xlabel('nox')
ax1.set_ylabel('medv')
ax2.scatter(x='black', y='tax', data=boston)
ax2.set_xlabel('black')
ax2.set_ylabel('tax')
# Out:
# Text(0,0.5,'tax')

# %% [markdown]
# Nitrogen oxides concentration reaches highest values for lowest median of value of owner-occupied homes.
# The proportion of black people is 0 or close to it only for towns with highest full-value property-tax rate.

# %% [markdown]
# **10. (c) Are any of the predictors associated with per capita crime rate? If so, explain the relationship.**

# %%
new_boston = boston.copy()

# %%
new_boston.index = new_boston['crim']
new_boston.plot(subplots=True, style='o', figsize=(16,40))
plt.xlim(new_boston['crim'].min(), new_boston['crim'].max())
# Out:
# (0.0063200000000000001, 88.976200000000006)

# %% [markdown]
# * Crime rate increases only there exist residential land zoned for lots over 25,000 sq.ft
# * Crime rate is significantly higher when non-retail business acres per town take about 20%. It's decreasing for higher and lower value of this proportion.
# * Not bounding the Charles River seems to be connected with high crime rate.
# * Higher nitrogen oxides concentration, up to value of 0.8 implies higher crime rate.
# * Rooms number per dwelling having values between 5 and 7 are paired with higher crime rate.
# * The proportion owner-occupied units built prior to 1940 higher than 50% is connected to increasing crime rate.
# * Crime rate is higher for low weighted mean of distances to five Boston employment centres.
# * High accesibility to radial highway is connected with higher crime rate.
# * Crime rate reaches higher values only for property tax of. app USD700 per per USD10,000
# * Similarily, Pupil-Teacher ratio of 20 is paired with high crime rates.
# * Proportion of black people doesn't seem to be connected, high crime rates show for both low and high proportions.
# * There seems to be a linear correlation between increasing percent of low status population and increasing crimes rates.
# * The lower the median value of properties, the higher crime rates have been noted.

# %% [markdown]
# **10. (d) Do any of the suburbs of Boston appear to have particularly high crime rates? Tax rates? Pupil-teacher ratios? Comment on the range of each predictor.**

# %%
sns.distplot(boston['crim'], bins=25, kde=False)

# %% [markdown]
# Significant majority of towns have crime rates nearing 0. There are however single places that note crime rates above 20.

# %%
sns.distplot(boston['tax'], kde=False, bins=20)

# %% [markdown]
# There are two groups of towns with tax values wide apart. The lower tax towns have taxes in the range between 180 - 450. Towns in this group are fairly differentiated in terms of tax value. Second group is much more unifrom, almost all towns note taxes in the range USD 680-700.

# %%
sns.distplot(boston['ptratio'], kde=False)

# %% [markdown]
# There ratio has its peak at 20. The rest of results is is more r less evenly scattered through the whole range.

# %% [markdown]
# **10. (e) How many of the suburbs in this data set bound the Charles river?**

# %%
sum(boston['chas'])
# Out:
# 35

# %% [markdown]
# **10. (f) What is the median pupil-teacher ratio among the towns in this data set?**

# %%
boston['ptratio'].median()
# Out:
# 19.05

# %% [markdown]
# **10. (g) Which suburb of Boston has lowest median value of owner- occupied homes? What are the values of the other predictors for that suburb, and how do those values compare to the overall ranges for those predictors? Comment on your findings.**

# %%
boston[boston['medv'] == boston['medv'].min()]
# Out:
#                crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# Unnamed: 0
# 399         38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 406         67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
#
#             ptratio   black  lstat  medv
# Unnamed: 0
# 399            20.2  396.90  30.59   5.0
# 406            20.2  384.97  22.98   5.0

# %%
boston.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       black  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# There are two such suburbs of Boston. They share few common predictor values:
# * Both have no residential land zoned for lots over 25,000 sq.ft and the same proportion of non-retail business acres per town.
# * They do not bound the Charles river and nox concentration stays on the same, rather high level.
# * Number of rooms per dwelling stays below average, both consist of owner-occupied units built prior to 1940.
# * They are characterized by one of the lowest distance to employment centers, which implies the highest index of accessibility to radial highways and pushes the tax value to one of the highest.
# * They both note high pupil-teacher ratio, both note high proportion of black people.
# * They are differentiated only by crime rate and the ratio of low status population.

# %% [markdown]
# **10. (h) In this data set, how many of the suburbs average more than seven rooms per dwelling? More than eight rooms per dwelling? Comment on the suburbs that average more than eight rooms per dwelling.**

# %%
sum(boston['rm'] > 7)
# Out:
# 64

# %%
sum(boston['rm'] > 8)
# Out:
# 13

# %%
boston[boston['rm'] > 8]
# Out:
#                crim    zn  indus  chas     nox     rm   age     dis  rad  tax  \
# Unnamed: 0
# 98          0.12083   0.0   2.89     0  0.4450  8.069  76.0  3.4952    2  276
# 164         1.51902   0.0  19.58     1  0.6050  8.375  93.9  2.1620    5  403
# 205         0.02009  95.0   2.68     0  0.4161  8.034  31.9  5.1180    4  224
# 225         0.31533   0.0   6.20     0  0.5040  8.266  78.3  2.8944    8  307
# 226         0.52693   0.0   6.20     0  0.5040  8.725  83.0  2.8944    8  307
# 227         0.38214   0.0   6.20     0  0.5040  8.040  86.5  3.2157    8  307
# 233         0.57529   0.0   6.20     0  0.5070  8.337  73.3  3.8384    8  307
# 234         0.33147   0.0   6.20     0  0.5070  8.247  70.4  3.6519    8  307
# 254         0.36894  22.0   5.86     0  0.4310  8.259   8.4  8.9067    7  330
# 258         0.61154  20.0   3.97     0  0.6470  8.704  86.9  1.8010    5  264
# 263         0.52014  20.0   3.97     0  0.6470  8.398  91.5  2.2885    5  264
# ...

# %% [markdown]
# * Low crime rates
# * Taxes in the lower group
# * Low lstat
